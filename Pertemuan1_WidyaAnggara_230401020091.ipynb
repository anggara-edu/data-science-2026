# %% [markdown]
# # Pertemuan 1 - Pengenalan Data Science
#
# Nama: Widya Anggara
# NIM: 230401020091
# Kelas: IF401

# %%
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
nama = "Widya Anggara"
angkatan = 2024
ipk = 3.39
aktif = True

print(f"Nama     : {nama}")
print(f"Angkatan : {angkatan}")
print(f"IPK      : {ipk}")
print(f"Aktif    : {aktif}")

print("\nTipe Data:")
print(type(nama))
print(type(angkatan))
print(type(ipk))
print(type(aktif))
# Out:
# Nama     : Widya Anggara
# Angkatan : 2024
# IPK      : 3.39
# Aktif    : True
#
# Tipe Data:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]

print("Tools Data Science yang akan dipelajari:")

for i, tool in enumerate(tools, 1):
    print(f"{i}. {tool}")
# Out:
# Tools Data Science yang akan dipelajari:
# 1. Python
# 2. Google Colab
# 3. Jupyter Notebook
# 4. GitHub

# %%
def perkenalan(nama, prodi, angkatan):
    """
    Fungsi untuk menampilkan perkenalan mahasiswa.
    """
    return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Widya Anggara", "Informatika", 2024)

print(hasil)
# Out:
# Hai! Saya Widya Anggara dari Informatika, angkatan 2024.
